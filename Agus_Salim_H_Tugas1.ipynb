# %% [markdown]
# <a href="https://colab.research.google.com/github/rianbtk/PC_VK-GENAP-2021/blob/main/Agus_Salim_H_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# list image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan iamage
# loop tia url
for url in urls :
  image = io.imread(url)                            # read image
  image = cv.resize(image,(0,0),fx=0.5,fy=0.5)   # resize image
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   # convert color
  final_frame = cv.hconcat((image, image_2))       # concate image
  cv2_imshow (final_frame)
  print ('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F39ECD6FEF0>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F39ECD6F9E8>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F39ECD74160>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print ("resolusi gambar : tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi gambar : tinggi x lebar =  286 x 400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F39ECD4DA58>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F39ECD4D0F0>

# %%
# membuat garis vertikal di gambar

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
  image_4[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F39EF3B9828>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  #membuat garis menyilang ditengah image
line = (0,0)
line2 = (400,0)

lineend = (400,286)
lineend2 = (0,286)

cv.line(image_3, line, lineend, (255,255,255))
cv.line(image_3, line2, lineend2, (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F39E47512E8>
